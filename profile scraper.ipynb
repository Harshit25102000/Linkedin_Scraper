# %%
import requests, time, random
# !pip install selenium
from bs4 import BeautifulSoup
from selenium import webdriver

# %%
def read_credentials_from_file(file_path):
    with open(file_path, 'r') as file:
        email = file.readline().strip()
        password = file.readline().strip()
    return email, password

# %%
file_path = 'LinkedinCredentials.txt'
email, password = read_credentials_from_file(file_path)

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
service = Service(executable_path=r"C:\Users\admin\Downloads\chromedriver-win64\chromedriver-win64\chromedriver.exe")
options = webdriver.ChromeOptions()
options.binary_location = r'C:\Users\admin\Downloads\chrome-win64\chrome-win64\chrome.exe'

#browser = webdriver.Chrome('chromedriver.exe')
browser=webdriver.Chrome(service=service, options=options)

browser.get('https://www.linkedin.com/uas/login')
#file = open('config.txt')
#lines = file.readlines()
username = email
password = password


#elementID = browser.find_element_by_id('username')
elementID = browser.find_element(By.ID, 'username')
elementID.send_keys(username)

elementID = browser.find_element(By.ID, 'password')
elementID.send_keys(password)

elementID.submit()

# %%
link = 'https://www.linkedin.com/in/avitechsmith/'

browser.get(link)

# %%
SCROLL_PAUSE_TIME = 5

# Get scroll height
last_height = browser.execute_script("return document.body.scrollHeight")

for i in range(3):
    # Scroll down to bottom
    browser.execute_script("window.scrollTo(0, document.body.scrollHeight);")

    # Wait to load page
    time.sleep(SCROLL_PAUSE_TIME)

    # Calculate new scroll height and compare with last scroll height
    new_height = browser.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

# %%
src = browser.page_source
soup = BeautifulSoup(src, 'lxml')
soup
# Out:
# <html class="theme theme--mercado artdeco windows" lang="en"><head>
# <script type="application/javascript">!function(i,n){void 0!==i.addEventListener&&void 0!==i.hidden&&(n.liVisibilityChangeListener=function(){i.hidden&&(n.liHasWindowHidden=!0)},i.addEventListener("visibilitychange",n.liVisibilityChangeListener))}(document,window);</script>
# <title>(9) Avi Shah | LinkedIn</title>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta class="mercado-icons-sprite" content="https://static.licdn.com/sc/h/cjy8ve6xop83bql2j8j08ov0a" id="artdeco-icons/static/images/sprite-asset" name="asset-url"/>
# <meta content="" name="description"/>
# <meta content="notranslate" name="google"/>
# <meta content="voyager-web" name="service"/>
# <meta content="#ffffff" id="theme-color-meta-tag" name="theme-color"/>
# <meta content="width=device-width, initial-scale=1.0, minimum-scale=1.0" name="viewport"/>
# ...

# %%
soup.prettify()
# Out:
# '<html class="theme theme--mercado artdeco windows" lang="en">\n <head>\n  <script type="application/javascript">\n   !function(i,n){void 0!==i.addEventListener&&void 0!==i.hidden&&(n.liVisibilityChangeListener=function(){i.hidden&&(n.liHasWindowHidden=!0)},i.addEventListener("visibilitychange",n.liVisibilityChangeListener))}(document,window);\n  </script>\n  <title>\n   (9) Avi Shah | LinkedIn\n  </title>\n  <meta charset="utf-8"/>\n  <meta content="IE=edge" http-equiv="X-UA-Compatible"/>\n  <meta class="mercado-icons-sprite" content="https://static.licdn.com/sc/h/cjy8ve6xop83bql2j8j08ov0a" id="artdeco-icons/static/images/sprite-asset" name="asset-url"/>\n  <meta content="" name="description"/>\n  <meta content="notranslate" name="google"/>\n  <meta content="voyager-web" name="service"/>\n  <meta content="#ffffff" id="theme-color-meta-tag" name="theme-color"/>\n  <meta content="width=device-width, initial-scale=1.0, minimum-scale=1.0" name="viewport"/>\n  <meta content="https://stat
# ...

# %%
name_loc = soup.find_all('ul')
name = name_loc[0].find('li').get_text().strip()
name
# Out:
# 'new feed updates notifications\n\n\n\n\n\n\n\n\n\n\n    Home'

# %%
a=0
for i in name_loc:
    print(a)
    print(i.find('li').get_text().strip())
    a=a+1
# Out:
# 0
# new feed updates notifications
#
#
#
#
#
#
#
#
#
#
#     Home
# 1
# Send profile in a message
# 2
# Futures First
# 3
# 1,794 followers
# 4
#
# 5
# Send profile in a message
# 6
# Avi is celebrating 2 years at Google Developer Student ClubsAvi is celebrating 2 years at Google Developer Student Clubs
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#               Message
# 7
# Message
# 8
# Message
# 9
# DocumentDocument
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Avi_shah_resume.pdfAvi_shah_resume.pdf
# 10
# 53
# 11
# Avi Shah reposted this • 1mo1mo
#
#
#
#
#
#
# Futures First is hiring for Quant and Algo Development
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Intern
#
#
#
#
# Job by Futures First
#
#
#
#
# Hyderabad, Telangana, India (On-site)
#
#
#
#
#
#
#
#
#
# 7
#
#
#
#
#
#               1 comment
# 12
# 7
# 13
# 271
# 14
# 121
# 15
# Quant Algo Developer Quant Algo Developer
#
#
#
#
#
# Futures First · InternshipFutures First · Internship
#
#
# ...

# %% [markdown]
# # number of connections

# %%
def remove_newlines(input_string):
    return input_string.replace('\n', '')

# %%
print(name_loc[3].find('li').get_text().strip())
# Out:
# 1,794 followers

# %%
all=soup.find_all('li',class_="text-body-small")
print(all)
info=[]
for i in all:
    info.append(remove_newlines(i.get_text()))
print(info)
# Out:
# [<li class="text-body-small t-black--light inline-block">
# <span class="t-bold">1,794</span> followers
#     </li>, <li class="text-body-small">
# <a class="ember-view" href="/search/results/people/?connectionOf=%5B%22ACoAACNHbvkBNA-naim_3AdHVHhA7RTvdFfHEQ0%22%5D&amp;network=%5B%22F%22%2C%22S%22%5D&amp;origin=MEMBER_PROFILE_CANNED_SEARCH" id="ember211">
# <span class="link-without-visited-state">
# <span class="t-bold">500+</span> connections
#           </span>
# </a>
# </li>]
# ['1,794 followers    ', '500+ connections          ']

# %% [markdown]
# # Home Page Posts code below

# %%
#print(name_loc[14])

# %%
ul_element = soup.find('ul', class_='display-flex flex-wrap list-style-none justify-space-between')
print(ul_element)
# Out:
# <ul class="display-flex flex-wrap list-style-none justify-space-between">
# <li class="profile-creator-shared-feed-update__mini-container">
# <div>
# <div class="profile-creator-shared-feed-update__mini-update display-flex flex-column">
# <!-- --> <a aria-label="View full post. Avi Shah reposted this • 1mo" class="app-aware-link feed-mini-update-optional-navigation-context-wrapper" data-test-app-aware-link="" href="https://www.linkedin.com/feed/update/urn:li:activity:7064163873792135169?updateEntityUrn=urn%3Ali%3Afs_updateV2%3A%28urn%3Ali%3Aactivity%3A7064163873792135169%2CFEED_DETAIL%2CEMPTY%2CDEFAULT%2Cfalse%29" tabindex="0">
# <div class="pt1 ph4 t-12 t-black--light">
# <span class="feed-mini-update-contextual-description__text">
# <span aria-hidden="true"><strong><!-- -->Avi Shah<!-- --></strong><span class="white-space-pre"> </span>reposted this • 1mo<!-- --></span><span class="visually-hidden"><!-- -->1mo<!-- --></span>
# </span>
# </div>
# </a>
# ...

# %%
res=ul_element.find_all('span', {'dir': 'ltr'})
res_time=ul_element.find_all('span', class_="feed-mini-update-contextual-description__text")

for i in res:
    print(remove_newlines(i.get_text()))
for i in res_time:
    print(remove_newlines(i.get_text()))
# Out:
# Futures First is hiring for Quant and Algo Development
# Intern
#
# I’m happy to share that I’m starting a new position as Quant Algo Developer Intern at Futures First!
# Avi Shah reposted this • 1mo1mo
# Avi Shah reposted this • 2mo2mo
# Avi Shah posted this • 6mo6mo

# %% [markdown]
# # home page posts code end

# %%
all_a=  ul_element.find_all('a',{'aria-label': True})
filtered_a = [a for a in all_a if not a.find(class_="app-aware-link")]
print(filtered_a)
# Out:
# [<a aria-label="View full post. Harshit Singh posted this • 3d" class="app-aware-link feed-mini-update-optional-navigation-context-wrapper" data-test-app-aware-link="" href="https://www.linkedin.com/feed/update/urn:li:activity:7077014246168903680?updateEntityUrn=urn%3Ali%3Afs_updateV2%3A%28urn%3Ali%3Aactivity%3A7077014246168903680%2CFEED_DETAIL%2CEMPTY%2CDEFAULT%2Cfalse%29" tabindex="0">
# <div class="pt1 ph4 t-12 t-black--light">
# <span class="feed-mini-update-contextual-description__text">
# <span aria-hidden="true"><strong><!-- -->Harshit Singh<!-- --></strong><span class="white-space-pre"> </span>posted this • 3d<!-- --></span><span class="visually-hidden"><!-- -->3d<!-- --></span>
# </span>
# </div>
# ...

# %% [markdown]
# # All posts code

# %%
posts_link=link+'recent-activity/all/'  
posts_link
# Out:
# 'https://www.linkedin.com/in/avitechsmith/recent-activity/all/'

# %%
browser.get(posts_link)
SCROLL_PAUSE_TIME = 5

# Get scroll height
last_height = browser.execute_script("return document.body.scrollHeight")

for i in range(3):
    # Scroll down to bottom
    browser.execute_script("window.scrollTo(0, document.body.scrollHeight);")

    # Wait to load page
    time.sleep(SCROLL_PAUSE_TIME)

    # Calculate new scroll height and compare with last scroll height
    new_height = browser.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

# %%
src = browser.page_source
psoup = BeautifulSoup(src, 'lxml')
psoup
# Out:
# <html class="theme theme--mercado artdeco windows" lang="en"><head>
# <script type="application/javascript">!function(i,n){void 0!==i.addEventListener&&void 0!==i.hidden&&(n.liVisibilityChangeListener=function(){i.hidden&&(n.liHasWindowHidden=!0)},i.addEventListener("visibilitychange",n.liVisibilityChangeListener))}(document,window);</script>
# <title>(9) Activity | Avi Shah | LinkedIn</title>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta class="mercado-icons-sprite" content="https://static.licdn.com/sc/h/cjy8ve6xop83bql2j8j08ov0a" id="artdeco-icons/static/images/sprite-asset" name="asset-url"/>
# <meta content="" name="description"/>
# <meta content="notranslate" name="google"/>
# <meta content="voyager-web" name="service"/>
# <meta content="#ffffff" id="theme-color-meta-tag" name="theme-color"/>
# <meta content="width=device-width, initial-scale=1.0, minimum-scale=1.0" name="viewport"/>
# ...

# %%
post_container=psoup.find('ul',class_="display-flex flex-wrap list-style-none justify-center")
posts=post_container.find_all('li',class_="profile-creator-shared-feed-update__container")
for post in posts:
    print(print(post))
    print("\n---------------------------------x--------------------------------------")
# Out:
# <li class="profile-creator-shared-feed-update__container">
# <div>
# <div class="relative">
# <div class="profile-creator-shared-feed-update__anchor"></div>
# <div class="feed-shared-update-v2 feed-shared-update-v2--minimal-padding full-height relative artdeco-card" data-urn="urn:li:activity:7064163873792135169" id="ember55">
# <div>
# <div role="status">
# <!-- --> </div>
# <h2 class="visually-hidden">
#               Feed post
#           </h2>
# <div class="update-components-actor display-flex update-components-actor--with-control-menu">
# <!-- -->
# <a aria-label="View: Avi Shah • 1st Quant Algo Development @Futures First , BS in Data Science from IIT Madras 1mo •   " class="app-aware-link update-components-actor__container-link relative display-flex flex-grow-1" data-test-app-aware-link="" href="https://www.linkedin.com/in/avitechsmith?miniProfileUrn=urn%3Ali%3Afs_miniProfile%3AACoAACNHbvkBNA-naim_3AdHVHhA7RTvdFfHEQ0" target="_self">
# ...

# %%
for post in posts:
    print(post.find_all('span',dir="ltr"))
    print("\n----------------------------------------x--------------------------------------------")
# Out:
# [<span dir="ltr">Avi Shah</span>, <span dir="ltr"><a data-attribute-index="0" data-entity-type="MINI_COMPANY" href="https://www.linkedin.com/company/futures-first-info--services-pvt--ltd-/">Futures First</a>  is hiring for Quant and Algo Development </span>, <span dir="ltr">Suraj Sanka</span>, <span dir="ltr">Check out this job at Futures First: <a data-attribute-index="0" href="https://lnkd.in/g-m7KCEe">https://lnkd.in/g-m7KCEe</a></span>, <span dir="ltr">Intern</span>]
#
# ----------------------------------------x--------------------------------------------
# ...

# %%
for post in posts:
    each_post=post.find_all('span',dir="ltr")
    for i in each_post:
        print(i.get_text())
        print("\n")
        
    print("\n----------------------------------------x--------------------------------------------")
# Out:
# Avi Shah
#
#
# Futures First  is hiring for Quant and Algo Development
#
#
# Suraj Sanka
#
#
# Check out this job at Futures First: https://lnkd.in/g-m7KCEe
#
#
# Intern
#
#
#
# ----------------------------------------x--------------------------------------------
# NSE India
#
#
# Congratulations MOS Utility Limited on getting listed on NSE Emerge today! Public Issue was of Rs. 4996.54 lakhs at an issue price of Rs. 76 per share.  #NSE #Listing #IPO #NSEIndia #StockMarket #ShareMarket #MOSUtility
#
#
#
# ----------------------------------------x--------------------------------------------
# Avi Shah
#
#
# I’m happy to share that I’m starting a new position as Quant Algo Developer Intern at Futures First!
#
#
#
# ----------------------------------------x--------------------------------------------
# Avi Shah
#
#
# ...
