# %%
import requests, time, random
# !pip install selenium
from bs4 import BeautifulSoup
from selenium import webdriver

# %%
def read_credentials_from_file(file_path):
    with open(file_path, 'r') as file:
        email = file.readline().strip()
        password = file.readline().strip()
    return email, password

# %%
file_path = 'LinkedinCredentials.txt'
email, password = read_credentials_from_file(file_path)

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
service = Service(executable_path=r"C:\Users\admin\Downloads\chromedriver-win64\chromedriver-win64\chromedriver.exe")
options = webdriver.ChromeOptions()
options.binary_location = r'C:\Users\admin\Downloads\chrome-win64\chrome-win64\chrome.exe'

#browser = webdriver.Chrome('chromedriver.exe')
browser=webdriver.Chrome(service=service, options=options)

browser.get('https://www.linkedin.com/uas/login')
#file = open('config.txt')
#lines = file.readlines()
username = email
password = password


#elementID = browser.find_element_by_id('username')
elementID = browser.find_element(By.ID, 'username')
elementID.send_keys(username)

elementID = browser.find_element(By.ID, 'password')
elementID.send_keys(password)

elementID.submit()

# %%
link = 'https://www.linkedin.com/company/microsoft/'

browser.get(link)

# %%
SCROLL_PAUSE_TIME = 5

# Get scroll height
last_height = browser.execute_script("return document.body.scrollHeight")

for i in range(3):
    # Scroll down to bottom
    browser.execute_script("window.scrollTo(0, document.body.scrollHeight);")

    # Wait to load page
    time.sleep(SCROLL_PAUSE_TIME)

    # Calculate new scroll height and compare with last scroll height
    new_height = browser.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

# %%
src = browser.page_source
soup = BeautifulSoup(src, 'lxml')
soup
# Out:
# <html class="theme theme--mercado artdeco windows" lang="en"><head>
# <script type="application/javascript">!function(i,n){void 0!==i.addEventListener&&void 0!==i.hidden&&(n.liVisibilityChangeListener=function(){i.hidden&&(n.liHasWindowHidden=!0)},i.addEventListener("visibilitychange",n.liVisibilityChangeListener))}(document,window);</script>
# <title>(9) Microsoft: Overview | LinkedIn</title>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta class="mercado-icons-sprite" content="https://static.licdn.com/sc/h/cjy8ve6xop83bql2j8j08ov0a" id="artdeco-icons/static/images/sprite-asset" name="asset-url"/>
# <meta content="" name="description"/>
# <meta content="notranslate" name="google"/>
# <meta content="voyager-web" name="service"/>
# <meta content="#ffffff" id="theme-color-meta-tag" name="theme-color"/>
# <meta content="width=device-width, initial-scale=1.0, minimum-scale=1.0" name="viewport"/>
# ...

# %%
name_loc = soup.find_all('ul')
name = name_loc[0].find('li').get_text().strip()
name
# Out:
# 'new feed updates notifications\n\n\n\n\n\n\n\n\n\n\n    Home'

# %%
a=0
for i in name_loc:
    print(a)
    print(i.find('li').get_text().strip())
    a=a+1
# Out:
# 0
# new feed updates notifications
#
#
#
#
#
#
#
#
#
#
#     Home
# 1
# Home
# 2
#
# 3
# Home
# 4
# MicrosoftMicrosoft
#
#
#
# 20,186,734 followers20,186,734 followers
#
#
#
# 1d •
#
#  1d •
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Did you know that AI can help save whales, fight heart disease, and make technology more accessible? Learn how Microsoft is investing in AI for Good to create a better world for everyone.
#
#
#
# …see more
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 136
#
#
#
#
#
#               3 comments
#
#
#
#
#
#
#             26 reposts
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#           Like
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     Comment
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Repost
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Send in a private message
# Send
# 5
# 136
# 6
# 803
# 7
# 1
# 8
# About
# 9
# Privacy Policy
# 10
# Questions?
#
#
#                       Visit our Help Center.
# 11
# Skype
#
#
#
#
# Software Development
#
#
#
#
# Acquisition
# ...

# %%
def remove_newlines(input_string):
    return input_string.replace('\n', '')

# %% [markdown]
# # connections and other info

# %%
all=soup.find_all('div',class_="org-top-card-summary-info-list__info-item")
print("Domain of work is ",remove_newlines(all[0].get_text()))
print("Address is ",remove_newlines(all[1].get_text()))
print("Followers are ",remove_newlines(all[2].get_text()))
# Out:
# Domain of work is        Software Development
# Address is          Redmond, Washington
# Followers are            20,195,715 followers

# %%
s=soup.find('a',id="ember28")
st=remove_newlines(s.get_text())
print(st)
# Out:
#           227,347 employees

# %% [markdown]
# # find posts

# %%
posts_link=link+'posts/?feedView=all'  
posts_link
# Out:
# 'https://www.linkedin.com/company/microsoft/posts/?feedView=all'

# %%
browser.get(posts_link)
SCROLL_PAUSE_TIME = 5

# Get scroll height
last_height = browser.execute_script("return document.body.scrollHeight")

for i in range(3):
    # Scroll down to bottom
    browser.execute_script("window.scrollTo(0, document.body.scrollHeight);")

    # Wait to load page
    time.sleep(SCROLL_PAUSE_TIME)

    # Calculate new scroll height and compare with last scroll height
    new_height = browser.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

# %%
src = browser.page_source
psoup = BeautifulSoup(src, 'lxml')
psoup
# Out:
# <html class="theme theme--mercado artdeco windows" lang="en"><head>
# <script type="application/javascript">!function(i,n){void 0!==i.addEventListener&&void 0!==i.hidden&&(n.liVisibilityChangeListener=function(){i.hidden&&(n.liHasWindowHidden=!0)},i.addEventListener("visibilitychange",n.liVisibilityChangeListener))}(document,window);</script>
# <title>(9) Microsoft: Posts | LinkedIn</title>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta class="mercado-icons-sprite" content="https://static.licdn.com/sc/h/cjy8ve6xop83bql2j8j08ov0a" id="artdeco-icons/static/images/sprite-asset" name="asset-url"/>
# <meta content="" name="description"/>
# <meta content="notranslate" name="google"/>
# <meta content="voyager-web" name="service"/>
# <meta content="#ffffff" id="theme-color-meta-tag" name="theme-color"/>
# <meta content="width=device-width, initial-scale=1.0, minimum-scale=1.0" name="viewport"/>
# ...

# %%
posts=psoup.find_all('div',class_="update-components-text relative feed-shared-update-v2__commentary")

for post in posts:
    p=post.find_all('span',dir="ltr")
  
    for i in p:
        print(i.get_text())
    print("----------------------------------------------x-----------------------------------------------")
# Out:
# Did you know that AI can help save whales, fight heart disease, and make technology more accessible? Learn how Microsoft is investing in AI for Good to create a better world for everyone.
# ----------------------------------------------x-----------------------------------------------
# We’re helping equip young people with the skills they need to succeed.Learn how the English Skills for Youth program is enhancing employment opportunities for young people, especially women, in underserved communities across India: https://msft.it/6040glLiM
# ----------------------------------------------x-----------------------------------------------
# ...

# %%
# Out:
# None
# ----------------------------------------------x-----------------------------------------------
# None
# ----------------------------------------------x-----------------------------------------------
# None
# ----------------------------------------------x-----------------------------------------------
